# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from textwrap import wrap


from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, OPTICS
from scipy.cluster.hierarchy import dendrogram

import re
import string
import time
from PIL import Image
from collections import Counter

import plotly.express as px

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import words as nltk_words
from nltk.corpus import stopwords
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

nltk.download('stopwords', download_dir='./resources')
nltk.download('punkt', download_dir='./resources')
nltk.download('wordnet', download_dir='./resources')
nltk.download('omw-1.4', download_dir='./resources')
nltk.download('words', download_dir='./resources')
nltk.data.path.append('./resources')
# Out:
# [nltk_data] Downloading package stopwords to ./resources...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to ./resources...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to ./resources...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to ./resources...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package words to ./resources...
# [nltk_data]   Package words is already up-to-date!

# %%
data = pd.read_csv('data/BBC_뉴스.csv')
data
# Out:
#                                                    title  \
# 0      Ukraine: Angry Zelensky vows to punish Russian...
# 1      War in Ukraine: Taking cover in a town under a...
# 2             Ukraine war 'catastrophic for global food'
# 3      Manchester Arena bombing: Saffie Roussos's par...
# 4      Ukraine conflict: Oil price soars to highest l...
# ...                                                  ...
# 10825  World Cup 2022: Switzerland 1-0 Cameroon - Bre...
# 10826  World Cup 2022: 'Furious' Wales take LGBTQ+ ri...
# 10827        China asks: Is World Cup on another planet?
# 10828  World Cup 2022: What has and hasn’t been banne...
# 10829  World Cup 2022: Brazil 2-0 Serbia - Richarliso...
#
#                              pubDate  \
# 0      Mon, 07 Mar 2022 08:01:56 GMT
# 1      Sun, 06 Mar 2022 22:49:58 GMT
# 2      Mon, 07 Mar 2022 00:14:42 GMT
# 3      Mon, 07 Mar 2022 00:05:40 GMT
# 4      Mon, 07 Mar 2022 08:15:53 GMT
# ...                              ...
# 10825  Thu, 24 Nov 2022 14:46:06 GMT
# 10826  Thu, 24 Nov 2022 05:49:11 GMT
# 10827  Thu, 24 Nov 2022 10:24:42 GMT
# 10828  Wed, 23 Nov 2022 23:38:52 GMT
# 10829  Thu, 24 Nov 2022 21:31:00 GMT
#
#                                                     guid  \
# 0       https://www.bbc.co.uk/news/world-europe-60638042
# 1       https://www.bbc.co.uk/news/world-europe-60641873
# 2           https://www.bbc.co.uk/news/business-60623941
# 3                 https://www.bbc.co.uk/news/uk-60579079
# 4           https://www.bbc.co.uk/news/business-60642786
# ...                                                  ...
# 10825      https://www.bbc.co.uk/sport/football/63657470
# 10826      https://www.bbc.co.uk/sport/football/63737709
# 10827  https://www.bbc.co.uk/news/world-asia-china-63...
# 10828          https://www.bbc.co.uk/news/world-63735559
# 10829      https://www.bbc.co.uk/sport/football/63657471
#
#                                                     link  \
# 0      https://www.bbc.co.uk/news/world-europe-606380...
# 1      https://www.bbc.co.uk/news/world-europe-606418...
# 2      https://www.bbc.co.uk/news/business-60623941?a...
# 3      https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4      https://www.bbc.co.uk/news/business-60642786?a...
# ...                                                  ...
# 10825  https://www.bbc.co.uk/sport/football/63657470?...
# 10826  https://www.bbc.co.uk/sport/football/63737709?...
# 10827  https://www.bbc.co.uk/news/world-asia-china-63...
# 10828  https://www.bbc.co.uk/news/world-63735559?at_m...
# 10829  https://www.bbc.co.uk/sport/football/63657471?...
#
#                                              description
# 0      The Ukrainian president says the country will ...
# 1      Jeremy Bowen was on the frontline in Irpin, as...
# 2      One of the world's biggest fertiliser firms sa...
# 3      The parents of the Manchester Arena bombing's ...
# 4      Consumers are feeling the impact of higher ene...
# ...                                                  ...
# 10825  Switzerland's Cameroon-born Breel Embolo score...
# 10826  Wales are "furious" players were threatened wi...
# 10827  Scenes of maskless crowds in Qatar anger viewe...
# 10828  Are supporters in Qatar managing to keep up wi...
# 10829  Richarlison scores twice - including a stunnin...
#
# [10830 rows x 5 columns]

# %%
sns.set_style('darkgrid')

# %%
STOPWORDS = stopwords.words('english')
pd.Series(STOPWORDS)
# Out:
# 0             i
# 1            me
# 2            my
# 3        myself
# 4            we
#          ...
# 174     weren't
# 175         won
# 176       won't
# 177      wouldn
# 178    wouldn't
# Length: 179, dtype: object

# %%
# BBC 언급 단어 Top15 추출
top_N = 15
a = data['title'].str.lower().str.replace(r'[^\w\s]', '', regex=True).str.cat(sep=' ')
words = list(filter(lambda w: w not in STOPWORDS, nltk.tokenize.word_tokenize(a)))
word_dist = nltk.FreqDist(words)
freq_title = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
freq_title
# Out:
#        Word  Frequency
# 0   ukraine        991
# 1       war        673
# 2      2022        520
# 3     world        499
# 4   england        490
# 5      says        453
# 6        uk        414
# 7       new        378
# 8       cup        367
# 9        us        319
# 10      win        281
# 11  russian        265
# 12   russia        241
# 13   papers        224
# 14   league        219

# %%
# BBC 언급 단어 Top15 그래프
freq_title.plot.barh(color='c', x='Word',y='Frequency',rot=0, figsize=(15,10))
plt.rc('font', family=font_name)
plt.title('BBC 최다 언급 단어 순위', fontsize=25)
plt.rc('font', size=18)
plt.xlabel('빈도', fontsize=20)
plt.ylabel('단어', fontsize=20)
# Out:
# Text(0, 0.5, '단어')
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50616 (\N{HANGUL SYLLABLE EON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
